# %%
import ms3

def absolute_localkey_to_numeral(localkey_abs: str, globalkey: str):
    lc_is_minor = localkey_abs.islower()
    gc_is_minor = globalkey.islower()
    lc_fifths = ms3.name2fifths(localkey_abs)
    gc_fifths = ms3.name2fifths(globalkey)
    lc_roman = ms3.fifths2rn(lc_fifths - gc_fifths, minor=gc_is_minor, auto_key=False)
    return lc_roman.lower() if lc_is_minor else lc_roman

# %%
dataset = ms3.Corpus("../assembled" , only_metadata_pieces=False, file_re="wtc",)
dataset
# Out:
# [reinward|default|all]
# Corpus 'assembled'
# ------------------
# Location: /home/laser/git/AugmentedNet/assembled
# View: This view is called 'reinward'. It
# 	- filters out file extensions requiring conversion (such as .xml),
# 	- excludes review files and folders, and
# 	- includes only files containing 'wtc'.
#
# All 24 pieces are listed in 'metadata.tsv':
#
#                        scores   labels
#                      detected detected
# wirwtc-bach-wtc-i-1         1        1
# wirwtc-bach-wtc-i-10        1        1
# wirwtc-bach-wtc-i-11        1        1
# wirwtc-bach-wtc-i-12        1        1
# wirwtc-bach-wtc-i-13        1        1
# wirwtc-bach-wtc-i-14        1        1
# wirwtc-bach-wtc-i-15        1        1
# wirwtc-bach-wtc-i-16        1        1
# wirwtc-bach-wtc-i-17        1        1
# wirwtc-bach-wtc-i-18        1        1
# wirwtc-bach-wtc-i-19        1        1
# wirwtc-bach-wtc-i-2         1        1
# wirwtc-bach-wtc-i-20        1        1
# wirwtc-bach-wtc-i-21        1        1
# wirwtc-bach-wtc-i-22        1        1
# wirwtc-bach-wtc-i-23        1        1
# wirwtc-bach-wtc-i-24        1        1
# wirwtc-bach-wtc-i-3         1        1
# wirwtc-bach-wtc-i-4         1        1
# wirwtc-bach-wtc-i-5         1        1
# wirwtc-bach-wtc-i-6         1        1
# wirwtc-bach-wtc-i-7         1        1
# wirwtc-bach-wtc-i-8         1        1
# wirwtc-bach-wtc-i-9         1        1
# 1316/1460 files are excluded from this view.
#
# 1316 files have been excluded based on their file name.

# %%
dataset.parse(parallel=False)
# Out:
# /home/laser/git/ms3/src/ms3/bs4_measures.py:225: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   excluded = df[dont_count].fillna(0).astype(bool)
# /home/laser/git/ms3/src/ms3/bs4_measures.py:225: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   excluded = df[dont_count].fillna(0).astype(bool)
# FIRST_BAR_MISSING_TEMPO_MARK_WARNING (29,) ms3.Corpus.assembled.wirwtc-bach-wtc-i-11 -- /home/laser/git/ms3/src/ms3/bs4_parser.py (line 2952) perform_checks():
# 	No metronome mark found in the first measure nor anywhere else in the score.
# /home/laser/git/ms3/src/ms3/bs4_measures.py:225: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   excluded = df[dont_count].fillna(0).astype(bool)
# /home/laser/git/ms3/src/ms3/bs4_parser.py:2951: UserWarning: No metronome mark found in the first measure nor anywhere else in the score.
# * Please add one at the very beginning and hide it if it's not from the original print edition.
# * Make sure to choose the rhythmic unit that corresponds to beats in this piece and to set another mark wherever that unit changes.
# * The tempo marks can be rough estimates, maybe cross-checked with a recording.
#   warnings.warn(warn_msg, UserWarning)
# FIRST_BAR_MISSING_TEMPO_MARK_WARNING (29,) ms3.Corpus.assembled.wirwtc-bach-wtc-i-12 -- /home/laser/git/ms3/src/ms3/bs4_parser.py (line 2952) perform_checks():
# 	No metronome mark found in the first measure nor anywhere else in the score.
# /home/laser/git/ms3/src/ms3/bs4_measures.py:225: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   excluded = df[dont_count].fillna(0).astype(bool)
# /home/laser/git/ms3/src/ms3/bs4_parser.py:2951: UserWarning: No metronome mark found in the first measure nor anywhere else in the score.
# * Please add one at the very beginning and hide it if it's not from the original print edition.
# * Make sure to choose the rhythmic unit that corresponds to beats in this piece and to set another mark wherever that unit changes.
# * The tempo marks can be rough estimates, maybe cross-checked with a recording.
#   warnings.warn(warn_msg, UserWarning)
# FIRST_BAR_MISSING_TEMPO_MARK_WARNING (29,) ms3.Corpus.assembled.wirwtc-bach-wtc-i-13 -- /home/laser/git/ms3/src/ms3/bs4_parser.py (line 2952) perform_checks():
# 	No metronome mark found in the first measure nor anywhere else in the score.
# /home/laser/git/ms3/src/ms3/bs4_measures.py:225: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   excluded = df[dont_count].fillna(0).astype(bool)
# /home/laser/git/ms3/src/ms3/bs4_parser.py:2951: UserWarning: No metronome mark found in the first measure nor anywhere else in the score.
# * Please add one at the very beginning and hide it if it's not from the original print edition.
# * Make sure to choose the rhythmic unit that corresponds to beats in this piece and to set another mark wherever that unit changes.
# * The tempo marks can be rough estimates, maybe cross-checked with a recording.
#   warnings.warn(warn_msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dataset.parse(parallel=False)
#
# File ~/git/ms3/src/ms3/corpus.py:1865, in Corpus.parse(self, view_name, level, parallel, only_new, labels_cfg, cols, infer_types, **kwargs)
#    1850 def parse(
#    1851     self,
#    1852     view_name=None,
#    (...)
#    1859     **kwargs,
#    1860 ):
#    1861     """Shorthand for executing parse_scores and parse_tsv at a time.
#    1862     Args:
#    1863       view_name:
#    1864     """
# -> 1865     self.parse_scores(
#    1866         level=level,
#    1867         parallel=parallel,
#    1868         only_new=only_new,
#    1869         labels_cfg=labels_cfg,
#    1870         view_name=view_name,
#    1871     )
#    1872     self.parse_tsv(
#    1873         view_name=view_name,
#    1874         level=level,
#    (...)
#    1878         **kwargs,
#    1879     )
#
# File ~/git/ms3/src/ms3/corpus.py:2007, in Corpus.parse_scores(self, level, parallel, only_new, labels_cfg, view_name, choose)
#    2005                 log_capture_handler.log_queue.extend(score.captured_logs)
#    2006 else:
# -> 2007     parsing_results = [
#    2008         parse_musescore_file(*params) for params in parse_this
#    2009     ]
#    2010     successful_results = {
#    2011         file.ix: score
#    2012         for file, score in zip(selected_files, parsing_results)
#    2013         if score is not None
#    2014     }
#    2015 successful = len(successful_results)
#
# File ~/git/ms3/src/ms3/corpus.py:2008, in <listcomp>(.0)
#    2005                 log_capture_handler.log_queue.extend(score.captured_logs)
#    2006 else:
#    2007     parsing_results = [
# -> 2008         parse_musescore_file(*params) for params in parse_this
#    2009     ]
#    2010     successful_results = {
#    2011         file.ix: score
#    2012         for file, score in zip(selected_files, parsing_results)
#    2013         if score is not None
#    2014     }
#    2015 successful = len(successful_results)
#
# File ~/git/ms3/src/ms3/corpus.py:3558, in parse_musescore_file(file, logger, logger_parent, labels_cfg, logger_cfg, read_only, ms)
#    3556 logger.debug(f"Attempting to parse {file}")
#    3557 try:
# -> 3558     score = Score(
#    3559         path, read_only=read_only, labels_cfg=labels_cfg, ms=ms, **logger_cfg
#    3560     )
#    3561     if score is None:
#    3562         logger.debug(f"Encountered errors when parsing {file}")
#
# File ~/git/ms3/src/ms3/score.py:1999, in Score.__init__(self, musescore_file, match_regex, read_only, labels_cfg, parser, ms, **logger_cfg)
#    1997 self.name2regex = match_regex
#    1998 if self.musescore_file is not None:
# -> 1999     self.parse_mscx()
#
# File ~/git/ms3/src/ms3/score.py:2888, in Score.parse_mscx(self, musescore_file, read_only, parser, labels_cfg)
#    2886         self.mscx.mscx_src = musescore_file
#    2887 else:
# -> 2888     self._mscx = MSCX(
#    2889         musescore_file,
#    2890         read_only=self.read_only,
#    2891         parser=self.parser,
#    2892         labels_cfg=self.labels_cfg,
#    2893         parent_score=self,
#    2894         **logger_cfg,
#    2895     )
#    2896 if self.mscx.has_annotations:
#    2897     self.mscx._annotations.infer_types(self.get_infer_regex())
#
# File ~/git/ms3/src/ms3/score.py:203, in MSCX.__init__(self, mscx_src, read_only, parser, labels_cfg, parent_score, **logger_cfg)
#     201 major_version = int(ms_version[0])
#     202 if major_version == 3:
# --> 203     self.parse_mscx()
#     204 elif major_version == 4:
#     205     self.logger.info(
#     206         f"This file has been created with MuseScore {ms_version} which I deal with experimentally for now."
#     207     )
#
# File ~/git/ms3/src/ms3/score.py:1029, in MSCX.parse_mscx(self)
#    1027 if self.parser in implemented_parsers:
#    1028     try:
# -> 1029         self._parsed = _MSCX_bs4.from_filepath(
#    1030             self.mscx_src, read_only=self.read_only, logger_cfg=self.logger_cfg
#    1031         )
#    1032     except Exception:
#    1033         self.logger.error(f"Failed parsing {self.mscx_src}.")
#
# File ~/git/ms3/src/ms3/bs4_parser.py:191, in _MSCX_bs4.from_filepath(cls, mscx_src, read_only, logger_cfg)
#     189 with open(mscx_src, "r", encoding="utf-8") as file:
#     190     soup = bs4.BeautifulSoup(file.read(), "xml")
# --> 191 created_object = cls(soup, read_only=read_only, logger_cfg=logger_cfg)
#     192 created_object.filepath = mscx_src
#     193 return created_object
#
# File ~/git/ms3/src/ms3/bs4_parser.py:277, in _MSCX_bs4.__init__(self, soup, read_only, logger_cfg)
#     271 """For each stuff that is to be treated as drumset score, keep a mapping from MIDI pitch (DataFrame index) to
#     272 note and instrument features.
#     273 The columns typically include ['head', 'line', 'voice', 'name', 'stem', 'shortcut'].
#     274 When creating note tables, the 'name' column will be populated with the names here rather than note names.
#     275 """
#     276 self.parse_soup()
# --> 277 self.parse_measures()
#     278 self.perform_checks()
#
# File ~/git/ms3/src/ms3/bs4_parser.py:2654, in _MSCX_bs4.parse_measures(self)
#    2649 # chord_info is a copy of the basic properties of the <Chord> that will be copied for each
#    2650 # included <Note> and <Rest>; whereas the event dict will be updated with additional
#    2651 # elements that make it into the "chords" and the "events" table
#    2653 tremolo_tag = event_node.find("Tremolo")
# -> 2654 if tremolo_tag:
#    2655     if tremolo_component > 0:
#    2656         raise NotImplementedError(
#    2657             "Chord with <Tremolo> follows another one with <Tremolo>"
#    2658         )
#
# KeyboardInterrupt:

# %%
import re
    
    

def replace_abc_dom9(label, localkey):
    
    def ninth_in_parentheses(match):
        nonlocal is_minor
        numeral = match.group(1)
        ninth = match.group(2)
        accidentals = match.group(3)
        modifiers = match.group(4)
        relative_key = match.group(5)
        if accidentals and "b" in accidentals:
            if relative_key: # we can correct this tacitly for relative minor keys (only those are captured by the rgx)
                ninth = "9"
            elif is_minor:   # for "normal" dominants, this is a mistake 
                raise ValueError(f"b9 does not make sense in a minor scale: {match.group(0)}")
            else: # in major, this is fine
                pass
            
            
        result = f"{numeral}({ninth}{modifiers})" if modifiers else f"{numeral}(+{ninth})"
        if relative_key:
            result += "/" + relative_key
        return result
        
    is_minor = localkey.islower()
    regex = r"(V|iv|iii|ii)((#+|b+)?9)(?:\((\S+)\))?(?:\/#*b*(vii|vi|v|iv|iii|ii|i))?"
    new_label = re.sub(regex, ninth_in_parentheses, label)
    if new_label != label:
        print(f"{label} => {new_label}")
    return new_label


def replace_tavern_dom9(label, localkey):
    
    def M9_in_parentheses(match):
        nonlocal is_minor
        dominant = match.group(1)
        return f"{dominant}(+#9)" if is_minor else f"{dominant}(+9)"
    
    def m9_in_parentheses(match):
        nonlocal is_minor
        dominant = match.group(1)
        return f"{dominant}(+9)" if is_minor else f"{dominant}(+b9)"
        
    is_minor = localkey.islower()
    M9_regex = r"(V(?:7|43|65))M9"
    new_label = re.sub(M9_regex, M9_in_parentheses, label)
    m9_regex = r"(V(?:7|43|65))b9"
    new_label = re.sub(m9_regex, m9_in_parentheses, new_label)
    if new_label != label:
        print(f"{label} => {new_label}")
    return new_label

for piece_id, piece in dataset.iter_pieces():
    print(piece_id, end=" -> ")
    _, labels_df = piece.get_parsed_tsv("labels")
    labels_df = labels_df.copy()
    labels_df.label = (
        labels_df.label
        .str.replace(r"(\d)/(\d)", r"\1\2", regex=True) # imported ABC's inversion digits are separated by /
        .str.replace("IV/64", "IV64", regex=False)  
        .str.replace("maj", "M", regex=False)           
        .str.replace(r"Cad64", r"V(64)", regex=False)    
        .str.replace("Vd", "V", regex=False)            # used in TAVERN for V2 but interpreted as V in rntxt
        .str.replace(r"(oø|ø)", "%", regex=True)
        .str.replace("N", "bII", regex=False)
        .str.replace("^bII#7$", "biiM7", regex=True)
        .str.replace("^bII6#5$", "biiM65", regex=True)
        .str.replace("^bII4#3$", "biiM43", regex=True)
        .str.replace("^IV6b5$", "IV65", regex=True)
        .str.replace("/viio", "/vii", regex=False) 
        .str.replace("^(V|I|v)4$", r"\1(4)", regex=True) 
        .str.replace("^ivb$", "iv", regex=True)
        .str.replace("^I6\+$", "I6", regex=True) # winterreise-d-911-16-letzte-hoffnung (should've been augmented)
        .str.replace("^(V|I|i)54$", r"\1(4)", regex=True)       # romantische-gesange-10-ida-aus-ariels-offenbarungen
        .str.replace("^i:$", "i", regex=True)
        .str.replace("^It53$", "#vo(b3)/V", regex=True)
        .str.replace("^It53\[add4\]$", "#vo(+4b3)/V", regex=True)
        .str.replace("^viio/42$", "viio42", regex=True) # this is meant as viiø42 but misinterpreted as viio42
        .str.replace(r"^(VI|iv|i)b7$", r"\g<1>7", regex=True)      # wir-openscore-liedercorpus-chaminade-amoroso    
        .str.replace("-VI", "VI", regex=False)          # tavern-beethoven-woo-75-a, m. 461
        .str.replace("\[\S+\]", "", regex=True)         # alternative labels in TAVERN
        .str.replace("I7+6", "I+M65", regex=False)      # tavern-beethoven-woo-65-a, m. 122
        .str.replace("Vi", "V7", regex=False)           # bps-16-op031-no1-1, m. 84
        .str.replace("V7IV", "V7/IV", regex=False)      # bps-26-op081a-les-adieux-1, m. 66
    ) 
    localkey = ms3.transform(labels_df, absolute_localkey_to_numeral, ["localkey_abs", "globalkey"])
    localkey_changes = (localkey != localkey.shift(1))
    modulations = (localkey.where(localkey_changes) + ".").fillna("")
    modulations.iat[0] = labels_df.iloc[0].globalkey + "."
    labels_df["localkey"] = localkey
    labels_df.label = ms3.transform(labels_df, replace_abc_dom9, ["label", "localkey"])
    labels_df.label = ms3.transform(labels_df, replace_tavern_dom9, ["label", "localkey"])
    labels_df.label = modulations + labels_df.label 
    piece.load_annotation_table_into_score(df=labels_df)
    score_id, score = piece.get_parsed("score")
    detached_labels = score["detached"].df
    incompatible_mask = detached_labels.regex_match.isna()
    if incompatible_mask.any():
        # break
        print("OK with problems")
    else:
        print("OK")
    score.attach_labels(
        key="detached",
        staff=None,
        voice=None,
        harmony_layer=1,
        check_for_clashes=True,
    )
    score.store_score(score.musescore_file)
    
detached_labels[incompatible_mask]

# %%
detached_labels[incompatible_mask].label.str.replace("^It53$", "#vo(b3)/V", regex=True)

# %%
_, notes = piece.get_facet("notes")
notes

# %%
fractions_list = notes.quarterbeats.tolist()
print(len(fractions_list))
fractions_list

# %%
import numpy as np

lcm = np.lcm.reduce([fr.denominator for fr in fractions_list])

vals = [int(fr.numerator * lcm / fr.denominator) for fr in fractions_list]
#vals.append(lcm)
vals

# %%
for

# %%
score.attach_labels(
        key="detached",
        staff=None,
        voice=None,
        harmony_layer=1,
        check_for_clashes=True,
    )
score.store_score(score.musescore_file)
score

# %%
score.detach_labels("detached")
score.store_score(score.musescore_file)
score
